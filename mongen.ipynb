# %%
# Do the calculations in order to remove parantheses
# and combine both text files into one text file
R.<F,Z,a,b,c,d,e,f,g,h,i,j,k,l> = PolynomialRing(GF(2),14)
with open('draft2.txt', 'r') as f:
    L = f.readlines()
    L = [l.strip() for l in L]

# %%
i = 0
lista = [None] * 4095
while i <= 4094:
    lista[i] = R(L[i])
    lista[i] = str(lista[i])
    i = i + 1
# Out:
# ['b', 'c', 'd', 'F + i', 'f', 'g', 'h', 'F + Z + e', 'j', 'k', 'l', 'F + Z + a + d', 'b*c', 'b*d', 'F*b + b*i', 'b*f', 'b*g', 'b*h', 'F*b + Z*b + b*e', 'b*j', 'b*k', 'b*l', 'F*b + Z*b + a*b + b*d', 'c*d', 'F*c + c*i', 'c*f', 'c*g', 'c*h', 'F*c + Z*c + c*e', 'c*j', 'c*k', 'c*l', 'F*c + Z*c + a*c + c*d', 'F*d + d*i', 'd*f', 'd*g', 'd*h', 'F*d + Z*d + d*e', 'd*j', 'd*k', 'd*l', 'F*d + Z*d + a*d + d^2', 'F*f + f*i', 'F*g + g*i', 'F*h + h*i', 'F^2 + F*Z + F*e + F*i + Z*i + e*i', 'F*j + i*j', 'F*k + i*k', 'F*l + i*l', 'F^2 + F*Z + F*a + F*d + F*i + Z*i + a*i + d*i', 'f*g', 'f*h', 'F*f + Z*f + e*f', 'f*j', 'f*k', 'f*l', 'F*f + Z*f + a*f + d*f', 'g*h', 'F*g + Z*g + e*g', 'g*j', 'g*k', 'g*l', 'F*g + Z*g + a*g + d*g', 'F*h + Z*h + e*h', 'h*j', 'h*k', 'h*l', 'F*h + Z*h + a*h + d*h', 'F*j + Z*j + e*j', 'F*k + Z*k + e*k', 'F*l + Z*l + e*l', 'F^2 + Z^2 + F*a + Z*a + F*d + Z*d + F*e + Z*e + a*e + d*e', 'j*k', 'j*l', 'F*j + Z*j + a*j + d*j', 'k*l', 'F*k + Z*k + a*k + d*k', 'F*l + Z*l + a*l + d*l', '
# ...

# %%
for i, l in enumerate(lista):
    lista[i] = l.replace('*', '')
    lista[i] = lista[i].replace('^2', '')
print(lista)
# Out:
# ['b', 'c', 'd', 'F + i', 'f', 'g', 'h', 'F + Z + e', 'j', 'k', 'l', 'F + Z + a + d', 'bc', 'bd', 'Fb + bi', 'bf', 'bg', 'bh', 'Fb + Zb + be', 'bj', 'bk', 'bl', 'Fb + Zb + ab + bd', 'cd', 'Fc + ci', 'cf', 'cg', 'ch', 'Fc + Zc + ce', 'cj', 'ck', 'cl', 'Fc + Zc + ac + cd', 'Fd + di', 'df', 'dg', 'dh', 'Fd + Zd + de', 'dj', 'dk', 'dl', 'Fd + Zd + ad + d', 'Ff + fi', 'Fg + gi', 'Fh + hi', 'F + FZ + Fe + Fi + Zi + ei', 'Fj + ij', 'Fk + ik', 'Fl + il', 'F + FZ + Fa + Fd + Fi + Zi + ai + di', 'fg', 'fh', 'Ff + Zf + ef', 'fj', 'fk', 'fl', 'Ff + Zf + af + df', 'gh', 'Fg + Zg + eg', 'gj', 'gk', 'gl', 'Fg + Zg + ag + dg', 'Fh + Zh + eh', 'hj', 'hk', 'hl', 'Fh + Zh + ah + dh', 'Fj + Zj + ej', 'Fk + Zk + ek', 'Fl + Zl + el', 'F + Z + Fa + Za + Fd + Zd + Fe + Ze + ae + de', 'jk', 'jl', 'Fj + Zj + aj + dj', 'kl', 'Fk + Zk + ak + dk', 'Fl + Zl + al + dl', 'bcd', 'Fbc + bci', 'bcf', 'bcg', 'bch', 'Fbc + Zbc + bce', 'bcj', 'bck', 'bcl', 'Fbc + Zbc + abc + bcd', 'Fbd + bdi', 'bdf', 'bdg', 'bdh', 'Fbd + 
# ...

# %%
with open('draft1.txt', 'r') as f:
    M = f.readlines()
    M = [l.strip() for l in M]

# %%
onoma_arxeiou = 'IOquestion12j.txt'
with open('IOquestion12.all_monomials.txt', 'w') as f:
    f.write(M[-1] + '\n')
    f.write(M[-2] + '\n')
    f.write(M[-3] + '\n')
    f.write(M[-4] + '\n')
    for i in range(len(lista)):
        if len(M[i]) == 1:
            f.write(str(M[i]) + '           ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 2:
            f.write(str(M[i]) + '          ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 3:
            f.write(str(M[i]) + '         ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 4:
            f.write(str(M[i]) + '        ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 5:
            f.write(str(M[i]) + '       ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 6:
            f.write(str(M[i]) + '      ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 7:
            f.write(str(M[i]) + '     ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 8:
            f.write(str(M[i]) + '    ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 9:
            f.write(str(M[i]) + '   ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 10:
            f.write(str(M[i]) + '  ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 11:
            f.write(str(M[i]) + ' ' + ' = ' + str(lista[i]) + '\n')
        elif len(M[i]) == 12:
            f.write(str(M[i]) + ' = ' + str(lista[i]) + '\n')
